# %%
y = True
z = 0
s = True

# %%
[y,z,s].count(True)
# Out:
# 2

# %% [markdown]
# ### Dictionary Filter

# %%
master_equipment = {
  'equip_dist': { 'CB Section': None,
                  'CS Laser Velocimeter': 173635,
                  'CT Temperature sensor-1 A': None,
                  'CT Temperature sensor-1 B': None,
                  'CT Temperature sensor-2 A': None,
                  'CT Temperature sensor-2 B': None,
                  'Cbox Approach Table HMD': 154575,
                  'Cbox CR1 HMD': 166300,
                  'Cbox CR2 HMD': 168300,
                  'Cbox CR3 HMD': 170300,
                  'Cbox Entry HMD': 164300,
                  'CoilBox Entry  Temperature sensor': None,
                  'CoilBox Entry  Temperature sensor A': None,
                  'CoilBox Entry  Temperature sensor B': None,
                  'Coiler Entry  Scan Temperature sensor': 312730,
                  'Coiler Entry  Temperature-1 sensor': 311730,
                  'Coiler Entry  Temperature-2 sensor': None,
                  'Coiler Entry Width Gauge ': None,
                  'Coiling Box': 168300,
                  'Crop Profile Gauge': None,
                  'Crop Shear': 178935,
                  'DC Entry CMD ': 313060,
                  'DC Section': None,
                  'Down Coiler 1': 329760,
                  'Down Coiler 2': 338760,
                  'Down Coiler 3': 347760,
                  'E1 Roll Bite HMD': 73245,
                  'E2 Roll Bite HMD': None,
                  'Edger 1': 74245,
                  'Edger 2': None,
                  'F1E Roll Bite HMD ': 185515,
                  'FM Delivery Flatness Gauge': 230155,
                  'FM Delivery Laser Velocimeter': 224540,
                  'FM Delivery Multi Function Gauge (tg, pg, fg)': 224540,
                  'FM Delivery Profile Gauge': None,
                  'FM Delivery Section': None,
                  'FM Delivery Temperature sensor': 228040,
                  'FM Delivery Temperature sensor 1': None,
                  'FM Delivery Temperature sensor 2': None,
                  'FM Delivery Thickness Gauge': None,
                  'FM Delivery Width Gauge': None,
                  'FM Edger': 186515,
                  'FM Entry HMD': 171335,
                  'FM Entry Temperature sensor': 174300,
                  'FM Entry Temperature sensor A': None,
                  'FM Entry Temperature sensor B': None,
                  'FM Section': None,
                  'FSB': 181115,
                  'Finishing Mill 1': 189040,
                  'Finishing Mill 2': 194540,
                  'Finishing Mill 3': 200040,
                  'Finishing Mill 4': 205540,
                  'Finishing Mill 5': 211040,
                  'Finishing Mill 6': 216540,
                  'Finishing Mill 7': 222040,
                  'Furnace Delivery': None,
                  'Furnace Entry': None,
                  'Furnace Section': None,
                  'HSB Entry HMD': 0,
                  'Hot Scale Breaker': 5948,
                  'MT Temperature sensor-1': 275900,
                  'MT Temperature sensor-1 A': None,
                  'MT Temperature sensor-1 B': None,
                  'MT Temperature sensor-2': None,
                  'MT Temperature sensor-2 A': None,
                  'MT Temperature sensor-2 B': None,
                  'MT Temperature sensor-3': None,
                  'MT Temperature sensor-3 A': None,
                  'MT Temperature sensor-3 B': None,
                  'Pinch Roll for Dow Coiler 1': 329760,
                  'Pinch Roll for Dow Coiler 2': 338760,
                  'Pinch Roll for Dow Coiler 3': 347760,
                  'Press Entry Width Gauge': None,
                  'R1 Approach Table HMD': 36680,
                  'R1 Delivery HMD': 81145,
                  'R1 Delivery HMD 1': 83145,
                  'R1 Delivery HMD 2': 90145,
                  'R1 Delivery HMD 3': 121145,
                  'R1 Delivery Laser Velocimeter': 84475,
                  'R1 Delivery Multi Function Gauge (tg, pg, wg)': 84475,
                  'R1 Delivery Profile Gauge': None,
                  'R1 Delivery Sideguide': 83145,
                  'R1 Delivery Temperature sensor': 90925,
                  'R1 Delivery Temperature sensor A': None,
                  'R1 Delivery Temperature sensor B': None,
                  'R1 Delivery Thickness Gauge': None,
                  'R1 Delivery Width Gauge': None,
                  'R1 Entry HMD': 68245,
                  'R2 Delivery HMD': None,
                  'R2 Delivery HMD 1': None,
                  'R2 Delivery HMD 2': None,
                  'R2 Delivery Laser Velocimeter': None,
                  'R2 Delivery Multi Function Gauge (tg, pg, wg)': None,
                  'R2 Delivery Profile Gauge': None,
                  'R2 Delivery Sideguide': None,
                  'R2 Delivery Temperature sensor': None,
                  'R2 Delivery Temperature sensor A': None,
                  'R2 Delivery Temperature sensor B': None,
                  'R2 Delivery Thickness Gauge': None,
                  'R2 Delivery Width Gauge': None,
                  'R2 Entry HMD': None,
                  'RHF1 Delivery HMD': None,
                  'RM Entry Temperature sensor': 19180,
                  'RM Entry Temperature sensor A': None,
                  'RM Entry Temperature sensor B': None,
                  'RM Entry Width gauge': 71045,
                  'RM Section': None,
                  'Roughing Mill 1': 78145,
                  'Roughing Mill 2': None,
                  'Sizing Press': None,
                  'Slab Reject Table HMD': None,
                  'Surface Inspection': None,
                  'Surface Inspection (bottom)': 313060,
                  'Surface Inspection (top)': 231930},
  'equip_valid': { 'CB Section': False,
                   'CS Laser Velocimeter': True,
                   'CT Temperature sensor-1 A': False,
                   'CT Temperature sensor-1 B': False,
                   'CT Temperature sensor-2 A': False,
                   'CT Temperature sensor-2 B': False,
                   'Cbox Approach Table HMD': True,
                   'Cbox CR1 HMD': True,
                   'Cbox CR2 HMD': True,
                   'Cbox CR3 HMD': True,
                   'Cbox Entry HMD': True,
                   'CoilBox Entry  Temperature sensor': False,
                   'CoilBox Entry  Temperature sensor A': False,
                   'CoilBox Entry  Temperature sensor B': False,
                   'Coiler Entry  Scan Temperature sensor': True,
                   'Coiler Entry  Temperature-1 sensor': True,
                   'Coiler Entry  Temperature-2 sensor': False,
                   'Coiler Entry Width Gauge ': False,
                   'Coiling Box': True,
                   'Crop Profile Gauge': False,
                   'Crop Shear': True,
                   'DC Entry CMD ': True,
                   'DC Section': False,
                   'Down Coiler 1': True,
                   'Down Coiler 2': True,
                   'Down Coiler 3': True,
                   'E1 Roll Bite HMD': True,
                   'E2 Roll Bite HMD': False,
                   'Edger 1': True,
                   'Edger 2': False,
                   'F1E Roll Bite HMD ': True,
                   'FM Delivery Flatness Gauge': True,
                   'FM Delivery Laser Velocimeter': True,
                   'FM Delivery Multi Function Gauge (tg, pg, fg)': True,
                   'FM Delivery Profile Gauge': False,
                   'FM Delivery Section': False,
                   'FM Delivery Temperature sensor': True,
                   'FM Delivery Temperature sensor 1': False,
                   'FM Delivery Temperature sensor 2': False,
                   'FM Delivery Thickness Gauge': False,
                   'FM Delivery Width Gauge': False,
                   'FM Edger': True,
                   'FM Entry HMD': True,
                   'FM Entry Temperature sensor': True,
                   'FM Entry Temperature sensor A': False,
                   'FM Entry Temperature sensor B': False,
                   'FM Section': False,
                   'FSB': True,
                   'Finishing Mill 1': True,
                   'Finishing Mill 2': True,
                   'Finishing Mill 3': True,
                   'Finishing Mill 4': True,
                   'Finishing Mill 5': True,
                   'Finishing Mill 6': False,
                   'Finishing Mill 7': False,
                   'Furnace Delivery': False,
                   'Furnace Entry': False,
                   'Furnace Section': False,
                   'HSB Entry HMD': True,
                   'Hot Scale Breaker': True,
                   'MT Temperature sensor-1': True,
                   'MT Temperature sensor-1 A': False,
                   'MT Temperature sensor-1 B': False,
                   'MT Temperature sensor-2': False,
                   'MT Temperature sensor-2 A': False,
                   'MT Temperature sensor-2 B': False,
                   'MT Temperature sensor-3': False,
                   'MT Temperature sensor-3 A': False,
                   'MT Temperature sensor-3 B': False,
                   'Pinch Roll for Dow Coiler 1': True,
                   'Pinch Roll for Dow Coiler 2': True,
                   'Pinch Roll for Dow Coiler 3': True,
                   'Press Entry Width Gauge': False,
                   'R1 Approach Table HMD': True,
                   'R1 Delivery HMD': True,
                   'R1 Delivery HMD 1': True,
                   'R1 Delivery HMD 2': True,
                   'R1 Delivery HMD 3': True,
                   'R1 Delivery Laser Velocimeter': True,
                   'R1 Delivery Multi Function Gauge (tg, pg, wg)': True,
                   'R1 Delivery Profile Gauge': False,
                   'R1 Delivery Sideguide': True,
                   'R1 Delivery Temperature sensor': True,
                   'R1 Delivery Temperature sensor A': False,
                   'R1 Delivery Temperature sensor B': False,
                   'R1 Delivery Thickness Gauge': False,
                   'R1 Delivery Width Gauge': False,
                   'R1 Entry HMD': True,
                   'R2 Delivery HMD': False,
                   'R2 Delivery HMD 1': False,
                   'R2 Delivery HMD 2': False,
                   'R2 Delivery Laser Velocimeter': False,
                   'R2 Delivery Multi Function Gauge (tg, pg, wg)': False,
                   'R2 Delivery Profile Gauge': False,
                   'R2 Delivery Sideguide': False,
                   'R2 Delivery Temperature sensor': False,
                   'R2 Delivery Temperature sensor A': False,
                   'R2 Delivery Temperature sensor B': False,
                   'R2 Delivery Thickness Gauge': False,
                   'R2 Delivery Width Gauge': False,
                   'R2 Entry HMD': False,
                   'RHF1 Delivery HMD': False,
                   'RM Entry Temperature sensor': True,
                   'RM Entry Temperature sensor A': False,
                   'RM Entry Temperature sensor B': False,
                   'RM Entry Width gauge': True,
                   'RM Section': False,
                   'Roughing Mill 1': True,
                   'Roughing Mill 2': True,
                   'Sizing Press': False,
                   'Slab Reject Table HMD': False,
                   'Surface Inspection': False,
                   'Surface Inspection (bottom)': True,
                   'Surface Inspection (top)': True},
  'equipment': { 'CB Section': 300,
                 'CS Laser Velocimeter': 310,
                 'CT Temperature sensor-1 A': 523,
                 'CT Temperature sensor-1 B': 524,
                 'CT Temperature sensor-2 A': 526,
                 'CT Temperature sensor-2 B': 527,
                 'Cbox Approach Table HMD': 301,
                 'Cbox CR1 HMD': 306,
                 'Cbox CR2 HMD': 307,
                 'Cbox CR3 HMD': 308,
                 'Cbox Entry HMD': 305,
                 'CoilBox Entry  Temperature sensor': 302,
                 'CoilBox Entry  Temperature sensor A': 303,
                 'CoilBox Entry  Temperature sensor B': 304,
                 'Coiler Entry  Scan Temperature sensor': 528,
                 'Coiler Entry  Temperature-1 sensor': 522,
                 'Coiler Entry  Temperature-2 sensor': 525,
                 'Coiler Entry Width Gauge ': 602,
                 'Coiling Box': 309,
                 'Crop Profile Gauge': 312,
                 'Crop Shear': 311,
                 'DC Entry CMD ': 601,
                 'DC Section': 600,
                 'Down Coiler 1': 603,
                 'Down Coiler 2': 604,
                 'Down Coiler 3': 605,
                 'E1 Roll Bite HMD': 209,
                 'E2 Roll Bite HMD': 226,
                 'Edger 1': 210,
                 'Edger 2': 227,
                 'F1E Roll Bite HMD ': 407,
                 'FM Delivery Flatness Gauge': 509,
                 'FM Delivery Laser Velocimeter': 508,
                 'FM Delivery Multi Function Gauge (tg, pg, fg)': 501,
                 'FM Delivery Profile Gauge': 503,
                 'FM Delivery Section': 500,
                 'FM Delivery Temperature sensor': 505,
                 'FM Delivery Temperature sensor 1': 506,
                 'FM Delivery Temperature sensor 2': 507,
                 'FM Delivery Thickness Gauge': 502,
                 'FM Delivery Width Gauge': 504,
                 'FM Edger': 406,
                 'FM Entry HMD': 401,
                 'FM Entry Temperature sensor': 402,
                 'FM Entry Temperature sensor A': 403,
                 'FM Entry Temperature sensor B': 404,
                 'FM Section': 400,
                 'FSB': 405,
                 'Finishing Mill 1': 408,
                 'Finishing Mill 2': 409,
                 'Finishing Mill 3': 410,
                 'Finishing Mill 4': 411,
                 'Finishing Mill 5': 412,
                 'Finishing Mill 6': 413,
                 'Finishing Mill 7': 414,
                 'Furnace Delivery': 102,
                 'Furnace Entry': 101,
                 'Furnace Section': 100,
                 'HSB Entry HMD': 105,
                 'Hot Scale Breaker': 106,
                 'MT Temperature sensor-1': 513,
                 'MT Temperature sensor-1 A': 514,
                 'MT Temperature sensor-1 B': 515,
                 'MT Temperature sensor-2': 516,
                 'MT Temperature sensor-2 A': 517,
                 'MT Temperature sensor-2 B': 518,
                 'MT Temperature sensor-3': 519,
                 'MT Temperature sensor-3 A': 520,
                 'MT Temperature sensor-3 B': 521,
                 'Pinch Roll for Dow Coiler 1': 606,
                 'Pinch Roll for Dow Coiler 2': 607,
                 'Pinch Roll for Dow Coiler 3': 608,
                 'Press Entry Width Gauge': 204,
                 'R1 Approach Table HMD': 205,
                 'R1 Delivery HMD': 212,
                 'R1 Delivery HMD 1': 213,
                 'R1 Delivery HMD 2': 215,
                 'R1 Delivery HMD 3': 224,
                 'R1 Delivery Laser Velocimeter': 220,
                 'R1 Delivery Multi Function Gauge (tg, pg, wg)': 216,
                 'R1 Delivery Profile Gauge': 218,
                 'R1 Delivery Sideguide': 214,
                 'R1 Delivery Temperature sensor': 221,
                 'R1 Delivery Temperature sensor A': 222,
                 'R1 Delivery Temperature sensor B': 223,
                 'R1 Delivery Thickness Gauge': 217,
                 'R1 Delivery Width Gauge': 219,
                 'R1 Entry HMD': 207,
                 'R2 Delivery HMD': 229,
                 'R2 Delivery HMD 1': 230,
                 'R2 Delivery HMD 2': 232,
                 'R2 Delivery Laser Velocimeter': 237,
                 'R2 Delivery Multi Function Gauge (tg, pg, wg)': 233,
                 'R2 Delivery Profile Gauge': 235,
                 'R2 Delivery Sideguide': 231,
                 'R2 Delivery Temperature sensor': 238,
                 'R2 Delivery Temperature sensor A': 239,
                 'R2 Delivery Temperature sensor B': 240,
                 'R2 Delivery Thickness Gauge': 234,
                 'R2 Delivery Width Gauge': 236,
                 'R2 Entry HMD': 225,
                 'RHF1 Delivery HMD': 104,
                 'RM Entry Temperature sensor': 201,
                 'RM Entry Temperature sensor A': 202,
                 'RM Entry Temperature sensor B': 203,
                 'RM Entry Width gauge': 208,
                 'RM Section': 200,
                 'Roughing Mill 1': 211,
                 'Roughing Mill 2': 228,
                 'Sizing Press': 206,
                 'Slab Reject Table HMD': 103,
                 'Surface Inspection': 510,
                 'Surface Inspection (bottom)': 512,
                 'Surface Inspection (top)': 511}}

# %%
fm_stand_equip_id = {k: v for k, v in master_equipment['equipment'].items() if k.startswith('Finishing Mill')}

# %%
fm_stand_equip_id
# Out:
# {'Finishing Mill 1': 408,
#  'Finishing Mill 2': 409,
#  'Finishing Mill 3': 410,
#  'Finishing Mill 4': 411,
#  'Finishing Mill 5': 412,
#  'Finishing Mill 6': 413,
#  'Finishing Mill 7': 414}

# %%
max(fm_stand_equip_id, key=fm_stand_equip_id.get) if fm_stand_equip_id else None
# Out:
# 'Finishing Mill 7'

# %%
fm_stand_equip = {}
for k, v in master_equipment["equipment"].items():
    if k.startswith("Finishing Mill") and master_equipment['equip_valid'][k]:
        fm_stand_equip[k] = v

# %%
fm_stand_equip
# Out:
# {'Finishing Mill 1': 408,
#  'Finishing Mill 2': 409,
#  'Finishing Mill 3': 410,
#  'Finishing Mill 4': 411,
#  'Finishing Mill 5': 412}

# %%
max(fm_stand_equip, key=fm_stand_equip.get) if fm_stand_equip else None
# Out:
# 'Finishing Mill 5'
